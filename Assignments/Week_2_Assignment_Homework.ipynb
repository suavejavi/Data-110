# %% [markdown]
# <a href="https://colab.research.google.com/github/suavejavi/Data-110/blob/main/Assignments/Week_2_Assignment_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment 2 Data 201
#
# Javier Mantilla

# %% [markdown]
# Question 8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 8a.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
college = pd.read_csv("/content/drive/MyDrive/Data 201/Datasets/College.csv")

# %%
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# 8b

# %%
college2 = pd.read_csv('/content/drive/MyDrive/Data 201/Datasets/College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0': "College"}, axis=1)
college3 = college3.set_index('College')

# %%
college = college3

# %%
college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %% [markdown]
# 8c.

# %%
college3.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# 8d

# %%
pd.plotting.scatter_matrix(college3[['Top10perc','Apps','Enroll']])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# 8e.

# %%
college3.boxplot('Outstate', by='Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# 8f.

# %%
college['Elite'] = pd.cut(college['Top10perc'],
                          [0, 50, 100],
                          labels=['No', 'Yes'])

# %%
pd.value_counts(college['Elite'])
# Out:
# /tmp/ipykernel_7494/380355470.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(college['Elite'])
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college.boxplot('Outstate', by='Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# 8g.

# %%
college[['Apps', 'Accept', 'Enroll', 'Outstate']].hist(bins=99)
# Out:
# array([[<Axes: title={'center': 'Apps'}>,
#         <Axes: title={'center': 'Accept'}>],
#        [<Axes: title={'center': 'Enroll'}>,
#         <Axes: title={'center': 'Outstate'}>]], dtype=object)

# %% [markdown]
# 8h.

# %%
plt.scatter(college['Expend'], college['Grad.Rate'])
plt.xlabel("Expenditure per Student")
plt.ylabel("Graduation Rate")
plt.title("Expenditure vs. Graduation Rate")


plt.show()

# %% [markdown]
# There's no strong linear relationship between instructional expenditure and graduation rate, most schools cluster below 20,000, in spending with graduation rates spread widely from about 20% to 100%. Beyond roughly 20,000-30,000 in expenditure, the spread narrows and graduation rates settle mostly into a higher band (80-100%), suggesting a weak positive trend at the high-spending end. One notable outlier has a graduation rate above 100%, which is a data-entry error. (I would hope so)

# %% [markdown]
# Question 9

# %%
Auto = pd.read_csv("/content/drive/MyDrive/Data 201/Datasets/Auto.csv")

# %%
Auto.isna().sum()#the output of all 0s means that there are no NA values in any of the columns.
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
Auto["horsepower"] = Auto["horsepower"].replace("?", pd.NA)

# %%
Auto["horsepower"] = pd.to_numeric(Auto["horsepower"])

# %% [markdown]
# 9a.

# %%
Auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %% [markdown]
# MPG,discplacement, horsepower, weight, and acceleration are all Quantatative.
#
# Name, cylinders, year and origin are categorical.

# %% [markdown]
# 9b and 9c

# %%
Auto['mpg'].min(), Auto['mpg'].max(), Auto['mpg'].mean(), Auto['mpg'].std()
# Out:
# (9.0, 46.6, np.float64(23.51586901763224), 7.825803928946562)

# %%
Auto['displacement'].min(), Auto['displacement'].max(), Auto['displacement'].mean(), Auto['displacement'].std()
# Out:
# (68.0, 455.0, np.float64(193.53274559193954), 104.37958329992945)

# %%
Auto['horsepower'].min(), Auto['horsepower'].max(), Auto['horsepower'].mean(), Auto['horsepower'].std()
# Out:
# (46.0, 230.0, np.float64(104.46938775510205), 38.49115993282855)

# %%
Auto['weight'].min(), Auto['weight'].max(), Auto['weight'].mean(), Auto['weight'].std()
# Out:
# (1613, 5140, np.float64(2970.2619647355164), 847.9041194897246)

# %%
Auto['acceleration'].min(), Auto['acceleration'].max(), Auto['acceleration'].mean(), Auto['acceleration'].std()
# Out:
# (8.0, 24.8, np.float64(15.55566750629723), 2.7499952929761515)

# %% [markdown]
# 9d.

# %%
Auto_dropped = Auto.drop(Auto.index[9:85])
Auto_dropped
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %%
Auto_dropped['mpg'].min(), Auto_dropped['mpg'].max(), Auto_dropped['mpg'].mean(), Auto_dropped['mpg'].std()
# Out:
# (11.0, 46.6, np.float64(24.438629283489096), 7.908184248945195)

# %% [markdown]
# The range of the dropped version of mpgis 11 to 46.6 mpg.

# %%
Auto_dropped['displacement'].min(), Auto_dropped['displacement'].max(), Auto_dropped['displacement'].mean(), Auto_dropped['displacement'].std()
# Out:
# (68.0, 455.0, np.float64(187.04984423676012), 99.63538531961508)

# %% [markdown]
# The range of the dropped version displacement is 68.0 to 455.0 displacement.

# %%
Auto_dropped['horsepower'].min(), Auto_dropped['horsepower'].max(), Auto_dropped['horsepower'].mean(), Auto_dropped['horsepower'].std()
# Out:
# (46.0, 230.0, np.float64(100.95583596214512), 35.89556677713123)

# %% [markdown]
# The range of the dropped version of horsepower is 46 to 230 horsepower.

# %%
Auto_dropped['weight'].min(), Auto_dropped['weight'].max(), Auto_dropped['weight'].mean(), Auto_dropped['weight'].std()
# Out:
# (1649, 4997, np.float64(2933.96261682243), 810.6429384125482)

# %% [markdown]
# The range of the dropped version of weight is 1649 to 4997 lbs.

# %%
Auto_dropped['acceleration'].min(), Auto_dropped['acceleration'].max(), Auto_dropped['acceleration'].mean(), Auto_dropped['acceleration'].std()
# Out:
# (8.5, 24.8, np.float64(15.723052959501558), 2.6805138313971697)

# %% [markdown]
# The range of the dropped version of acceleration is 8.5 to 24.8 acceleration.

# %% [markdown]
# 9e.

# %%
plt.scatter(Auto['horsepower'], Auto['acceleration'])
plt.xlabel("Horsepower")
plt.ylabel("Acceleration")

plt.show()

# %% [markdown]
# This scatterplot shows how as the horsepower goes up, the acceleration goes down. This is surprising to me as I thought that more horsepower ment more speed, but it also means more weight because of the bigger engine size. So it is reasonable to say that because the weight will slow the acceleration as the engine size goes up.

# %%
plt.scatter(Auto['mpg'], Auto['weight'])
plt.xlabel("Miles per Gallon")
plt.ylabel("Weight (lbs)")

plt.show()

# %% [markdown]
# This scatterplot shows the relationship between Miles per Gallon and Weight. It shows that when the weight is at its highest, the miles per gallon is at its lowest. This is because the heavier the car the more gas it will use in a shorter amount of distance. But when the car is very light, the mpg reaches all the way into the 40's, which proves the reasoning that as the miles per gallon increases the weight decreases.

# %% [markdown]
# 9f.

# %% [markdown]
# I think that our last scatterplot helps us predict mpg because as the mpg increases, the weight decreases. But our first plot are other variables that can help predict mpg as I used horsepower as well. Horsepower can help predict mpg as the horsepower shows the power of the car, so the faster the car can go the more gas it will use up.

# %% [markdown]
# 10

# %% [markdown]
# 10a.

# %%
Boston = pd.read_csv("/content/drive/MyDrive/Data 201/Datasets/Boston.csv")
Boston
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio  lstat  medv
# ...

# %% [markdown]
# 10b.

# %% [markdown]
# There are 506 rows and 14 columns. The rows represent the observations, and the columns represent the variables.

# %% [markdown]
# 10c.

# %%
pd.plotting.scatter_matrix(Boston[['crim','age','dis','tax']])
# Out:
# array([[<Axes: xlabel='crim', ylabel='crim'>,
#         <Axes: xlabel='age', ylabel='crim'>,
#         <Axes: xlabel='dis', ylabel='crim'>,
#         <Axes: xlabel='tax', ylabel='crim'>],
#        [<Axes: xlabel='crim', ylabel='age'>,
#         <Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='dis', ylabel='age'>,
#         <Axes: xlabel='tax', ylabel='age'>],
#        [<Axes: xlabel='crim', ylabel='dis'>,
#         <Axes: xlabel='age', ylabel='dis'>,
#         <Axes: xlabel='dis', ylabel='dis'>,
#         <Axes: xlabel='tax', ylabel='dis'>],
#        [<Axes: xlabel='crim', ylabel='tax'>,
#         <Axes: xlabel='age', ylabel='tax'>,
#         <Axes: xlabel='dis', ylabel='tax'>,
#         <Axes: xlabel='tax', ylabel='tax'>]], dtype=object)

# %% [markdown]
# Towns with older houses (age) and distance to employment centers (dis) show a clear negative relationship, towns with older housing tend to sit closer to employment centers, while newer housing is farther out. This reflects typical urban development, with older neighborhoods near the urban core and newer construction spreading to the suburbs over time. The diagonal histograms support this: age is left-skewed (most towns have old housing) and dis is right-skewed (most towns are relatively close in), reinforcing that the two are closely tied rather than independent.

# %% [markdown]
# 10d.

# %% [markdown]
# Distance to employment centers (dis) shows a strong negative relationship with crime, nearly all high-crime towns are clustered at very low dis, and crime drops close to zero as distance increases. Age of housing stock (age) shows a positive association, with high-crime outliers becoming common only once age exceeds roughly 50-60, while towns with newer housing stay uniformly low-crime. Together, these suggest crime is concentrated in older towns located close to Boston's employment centers.

# %% [markdown]
# 10e.

# %%
Boston[['crim', 'tax', 'ptratio']].describe()
# Out:
#              crim         tax     ptratio
# count  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   18.455534
# std      8.601545  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.082045  279.000000   17.400000
# 50%      0.256510  330.000000   19.050000
# 75%      3.677083  666.000000   20.200000
# max     88.976200  711.000000   22.000000

# %% [markdown]
# * Crime - Yes, some of the suburbs in Boston have high crime rates, and there are clear outliers. The median is only 0.26 and the 75th percentile is 3.68 but the max reaches 88%, which is over 24 times the 75th percentile. This tells us that crime is very right skewed, the vast majority of towns have low crime rates, but a small amount have a very high crime rate. The range of crim is 0.0006 to 88.98.
#
# * Tax - Somewhat, the spread for tax is wide, but less extreme than crime. The median is 330 and the 75th precentile is 666, close to the max of 711. This suggests that a cluster of towns sit at a high tax rate near the top of the range. The range of tax is 187 to 711.
#
# * Ptratio - No, there isn't a big spread for this. It only ranges from 12 to 22, with a small sd of 2.16, which means no towns are crazy outliers for this variable.

# %% [markdown]
# 10f.

# %%
(Boston['chas'] == 1).sum()
# Out:
# np.int64(35)

# %% [markdown]
# There are 35 suburbs bound to the Charles River

# %% [markdown]
# 10g.

# %%
Boston['ptratio'].median()
# Out:
# 19.05

# %% [markdown]
# The median pupil-teacher ratio among the towns in this dataset is 19.05.

# %% [markdown]
# 10h.

# %%
idx_min = Boston['medv'] == Boston['medv'].min()
Boston.loc[idx_min]
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 398         399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24
# 405         406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24
#
#      tax  ptratio  lstat  medv
# 398  666     20.2  30.59   5.0
# 405  666     20.2  22.98   5.0

# %% [markdown]
# n total, two suburbs (rows 398 and 405) are tied for the lowest median home value at medv = 5.0. Both show extremely high crime, the oldest possible housing, small homes, high pollution, maximum highway access, and a high tax rate, with an elevated share of lower-status residents. Nearly every predictor for these suburbs sits at or near the extreme end of its overall range, age and rad hit the dataset max, crim and lstat are well above the 75th percentile, and dis/rm are near the low end. These low-value suburbs aren't explained by any single factor but by high crime, old/cramped housing, pollution, and heavy taxation all in the same towns at once, suggesting medv is shaped by an interaction of multiple predictors.

# %% [markdown]
# 10i.

# %%
idx_rm7 = Boston['rm'] > 7
Boston.loc[idx_rm7].shape[0]
# Out:
# 64

# %%
idx_rm8 = Boston['rm'] > 8
Boston.loc[idx_rm8].shape[0]
# Out:
# 13

# %%
Boston.loc[idx_rm8]
Boston.loc[idx_rm8].describe()
# Out:
#        Unnamed: 0       crim         zn      indus       chas        nox  \
# count   13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean   232.307692   0.718795  13.615385   7.078462   0.153846   0.539238
# std     60.915768   0.901640  26.298094   5.392767   0.375534   0.092352
# min     98.000000   0.020090   0.000000   2.680000   0.000000   0.416100
# 25%    225.000000   0.331470   0.000000   3.970000   0.000000   0.504000
# 50%    233.000000   0.520140   0.000000   6.200000   0.000000   0.507000
# 75%    258.000000   0.578340  20.000000   6.200000   0.000000   0.605000
# max    365.000000   3.474280  95.000000  19.580000   1.000000   0.718000
#
#               rm        age        dis        rad         tax    ptratio  \
# count  13.000000  13.000000  13.000000  13.000000   13.000000  13.000000
# mean    8.348538  71.538462   3.430192   7.461538  325.076923  16.361538
# std     0.251261  24.608723   1.883955   5.332532  110.971063   2.410580
# ...

# %% [markdown]
# 64 suburbs in the dataset average more than 7 rooms per dwelling. Only 13 suburbs average more than 8 rooms per dwelling. The suburbs averaging more than 8 rooms per dwelling look like wealthy and comfortable neighborhoods,they combine low crime, high home values, low lstat, and favorable school ratios, essentially the opposite profile of the suburbs found in part (h). This reinforces that rm (house size) tracks closely with overall neighborhood wealthiness in this dataset.
